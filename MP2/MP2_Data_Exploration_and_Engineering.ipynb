# %%
import pandas as pd

# %%
import numpy as np

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
datared= 'https://raw.githubusercontent.com/foxdocs/cph-bi-2024/main/Data/UCL-Wine/winequality-red.csv'

# %%
datawhite= 'https://raw.githubusercontent.com/foxdocs/cph-bi-2024/main/Data/UCL-Wine/winequality-white.csv'

# %% [markdown]
# #### Panda uses , not ; so you have to use delimiter so pandas think ; is ,

# %%
dred = pd.read_csv(datared, delimiter=';', header=0)

# %%
dwhite = pd.read_csv(datawhite, delimiter=';', header=0)

# %%
dred
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
dwhite
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %% [markdown]
# #### You have to add a new row in the data to have the wine type in the data but you need to make a copy of the dataset so the orginal is not changed and you use concat to merge the two datasets

# %%
dredCopy=dred.copy()

# %%
dwhiteCopy=dwhite.copy()

# %%
dredCopy['wine type'] = 'red'

# %%
dwhiteCopy['wine type'] = 'white'

# %%
datawine= pd.concat([dredCopy, dwhiteCopy], axis=0)

# %%
datawine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %% [markdown]
# ## Explore the data

# %%
print("Rows:", dred.shape[0], "Columns:", dred.shape[1])
# Out:
# Rows: 1599 Columns: 12

# %%
print("Rows:", dwhite.shape[0], "Columns:", dwhite.shape[1])
# Out:
# Rows: 4898 Columns: 12

# %%
print("Rows:", datawine.shape[0], "Columns:", datawine.shape[1])
# Out:
# Rows: 6497 Columns: 13

# %%
dred.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %%
dwhite.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %%
datawine.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# wine type                object
# dtype: object

# %% [markdown]
# #### 5 Calculate the descriptive statistics of the numeric data.

# %%
dred_stats=dred.describe()

# %%
dred_stats
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
# Averaged
dred_meanq = dred['quality'].mean()
dred_meana = dred['alcohol'].mean()
dred_meanfa = dred['fixed acidity'].mean()
dred_means= dred['residual sugar'].mean()
dred_medians= dred['residual sugar'].median()

# %%
dred_means
# Out:
# 2.53880550343965

# %%
dred_median=dred.quality.median()

# %%
dred_mode=dred.quality.mode()

# %%
# Standard deviation
dred_std=dred.quality.std()

# %%
minR = dred.min()

# %%
maxR = dred.max()

# %%
print("For red wine")
print("Minimum:")
print(minR)
print("")
print("Maximum:")
print(maxR)
# Out:
# For red wine
# Minimum:
# fixed acidity           4.60000
# volatile acidity        0.12000
# citric acid             0.00000
# residual sugar          0.90000
# chlorides               0.01200
# free sulfur dioxide     1.00000
# total sulfur dioxide    6.00000
# density                 0.99007
# pH                      2.74000
# sulphates               0.33000
# alcohol                 8.40000
# quality                 3.00000
# dtype: float64
#
# Maximum:
# fixed acidity            15.90000
# volatile acidity          1.58000
# citric acid               1.00000
# residual sugar           15.50000
# chlorides                 0.61100
# free sulfur dioxide      72.00000
# total sulfur dioxide    289.00000
# density                   1.00369
# pH                        4.01000
# sulphates                 2.00000
# alcohol                  14.90000
# quality                   8.00000
# dtype: float64

# %%
dwhite_stats=dwhite.describe()

# %%
# Average
dwhite_meanq=dwhite.quality.mean()
dwhite_meana=dwhite.alcohol.mean()
dwhite_meanfa=dwhite['fixed acidity'].mean() 
dwhite_means= dwhite['residual sugar'].mean()
dwhite_medians= dwhite['residual sugar'].median()

# %%
dwhite_median=dwhite.quality.median()

# %%
dwhite_mode=dwhite.quality.mode()

# %%
# Standard deviation
dwhite_std=dwhite.quality.std()

# %%
minW = dwhite.min()

# %%
maxW = dwhite.max()

# %%
print("For white wine")
print("Minimum:")
print(minW)
print("")
print("Maximum:")
print(maxW)
# Out:
# For white wine
# Minimum:
# fixed acidity           3.80000
# volatile acidity        0.08000
# citric acid             0.00000
# residual sugar          0.60000
# chlorides               0.00900
# free sulfur dioxide     2.00000
# total sulfur dioxide    9.00000
# density                 0.98711
# pH                      2.72000
# sulphates               0.22000
# alcohol                 8.00000
# quality                 3.00000
# dtype: float64
#
# Maximum:
# fixed acidity            14.20000
# volatile acidity          1.10000
# citric acid               1.66000
# residual sugar           65.80000
# chlorides                 0.34600
# free sulfur dioxide     289.00000
# total sulfur dioxide    440.00000
# density                   1.03898
# pH                        3.82000
# sulphates                 1.08000
# alcohol                  14.20000
# quality                   9.00000
# dtype: float64

# %%
datawine_stats=datawine.describe()

# %%
datawine_stats
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    6497.000000       6497.000000  6497.000000     6497.000000
# mean        7.215307          0.339666     0.318633        5.443235
# std         1.296434          0.164636     0.145318        4.757804
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.250000        1.800000
# 50%         7.000000          0.290000     0.310000        3.000000
# 75%         7.700000          0.400000     0.390000        8.100000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  6497.000000          6497.000000           6497.000000  6497.000000
# mean      0.056034            30.525319            115.744574     0.994697
# std       0.035034            17.749400             56.521855     0.002999
# ...

# %%
# Average numeric_only makes sure that red and white doenst interfere with the average, so only numbers are used
datawine_mean=datawine.quality.mean(numeric_only=True)

# %%
datawine_mean
# Out:
# 5.818377712790519

# %%
datawine_median=datawine.quality.median(numeric_only=True)
datawine_mean=datawine['residual sugar'].mean(numeric_only=True)

# %%
datawine_mode=datawine.quality.mode()

# %%
# Standard deviation
datawine_std=datawine.quality.std(numeric_only=True)

# %%
min = datawine.min(numeric_only=True)

# %%
max = datawine.max(numeric_only=True)

# %%
print("Minimum:")
print(min)
print("")
print("Maximum:")
print(max)
# Out:
# Minimum:
# fixed acidity           3.80000
# volatile acidity        0.08000
# citric acid             0.00000
# residual sugar          0.60000
# chlorides               0.00900
# free sulfur dioxide     1.00000
# total sulfur dioxide    6.00000
# density                 0.98711
# pH                      2.72000
# sulphates               0.22000
# alcohol                 8.00000
# quality                 3.00000
# dtype: float64
#
# Maximum:
# fixed acidity            15.90000
# volatile acidity          1.58000
# citric acid               1.66000
# residual sugar           65.80000
# chlorides                 0.61100
# free sulfur dioxide     289.00000
# total sulfur dioxide    440.00000
# density                   1.03898
# pH                        4.01000
# sulphates                 2.00000
# alcohol                  14.90000
# quality                   9.00000
# dtype: float64

# %%
dred[['quality', 'alcohol', 'fixed acidity']].hist(bins=10, figsize=(8, 6))
plt.suptitle('Histograms of Red Wine Quality, Alcohol and Fixed Acidity')
plt.show()

# %%
dwhite[['quality', 'alcohol', 'fixed acidity']].hist(bins=10, figsize=(8, 6))
plt.suptitle('Histograms of White Wine Quality, Alcohol and Fixed Acidity')
plt.show()

# %%
datawine[['quality', 'alcohol', 'fixed acidity']].hist(bins=10, figsize=(8, 6))
plt.suptitle('Histograms of Wine Quality, Alcohol and Fixed Acidity')
plt.show()

# %% [markdown]
# #### 6 Plot diagrams that visualize the differences in red and white wine samples

# %%
columns_compare = ['quality', 'alcohol', 'fixed acidity']

# %%
# Loop through each column and plot the histograms for red and white wines
for col in columns_compare:
    plt.figure(figsize=(8, 6))
    
    plt.hist(dred[col], bins=10, alpha=0.5, label='Red Wine', color='red')
    
    plt.hist(dwhite[col], bins=10, alpha=0.5, label='White Wine', color='blue')
    
    plt.title(f'Comparison of {col} between red and white wine')
    plt.xlabel(col)
    plt.ylabel('Amount')
    plt.legend()
    
    plt.show()

# %% [markdown]
# #### 6A Diagram explanation

# %% [markdown]
# they show the difference between the quality, alcohol and fixed acidity between the red and white wines

# %% [markdown]
# #### 6B

# %%
comparedq= dwhite_meanq - dred_meanq
comparedq
# Out:
# 0.2418868366841158

# %%
meansq = [dwhite_meanq, dred_meanq]
wine_types = ['White Wine', 'Red Wine']

# Create a bar plot
plt.figure(figsize=(8, 6))
plt.bar(wine_types, meansq, color=['blue', 'red'])

# Add labels and title
plt.ylabel('Mean Quality')
plt.title('Comparison of Mean Quality Between Red and White Wines')

# Show the plot
plt.show()

# %%
print(f"White wine has a slightly higher average quality with a difference of {comparedq:.3f}")
# Out:
# White wine has a slightly higher average quality with a difference of 0.242

# %% [markdown]
# ### 6C

# %%
compareda= dwhite_meana - dred_meana
compareda
# Out:
# 0.09128393332807327

# %%
meansa = [dwhite_meana, dred_meana]
wine_types = ['White Wine', 'Red Wine']

# Create a bar plot
plt.figure(figsize=(8, 6))
plt.bar(wine_types, meansa, color=['blue', 'red'])

# Add labels and title
plt.ylabel('Mean Alcohol')
plt.title('Comparison of Mean Alcohol Between Red and White Wines')

# Show the plot
plt.show()

# %%
print(f"White wine has a slightly higher average alcohol with a difference of {compareda:.4f}")
# Out:
# White wine has a slightly higher average alcohol with a difference of 0.0913

# %% [markdown]
# ### 6D

# %%
compareds= dwhite_means - dred_means
compareds
# Out:
# 3.852609359769824

# %%
comparedmedians= dwhite_medians - dred_medians
comparedmedians
# Out:
# 3.0

# %%
meanss = [dwhite_means, dred_means]
wine_types = ['White Wine', 'Red Wine']

# Create a bar plot
plt.figure(figsize=(8, 6))
plt.bar(wine_types, meanss, color=['blue', 'red'])

# Add labels and title
plt.ylabel('Mean Residual Sugar')
plt.title('Comparison of Mean Residual Sugar Between Red and White Wines')

# Show the plot
plt.show()

# %%
medians= [dwhite_medians, dred_medians]
wine_types = ['White Wine', 'Red Wine']

# Create a bar plot
plt.figure(figsize=(8, 6))
plt.bar(wine_types, medians, color=['blue', 'red'])

# Add labels and title
plt.ylabel('Median Residual Sugar')
plt.title('Comparison of Median Residual Sugar Between Red and White Wines')

# Show the plot
plt.show()

# %%
print(f"White wine has a slightly higher average residual sugar with a difference of Mean: {compareds:.2f} and Median: {comparedmedians:.2f}")
# Out:
# White wine has a slightly higher average residual sugar with a difference of Mean: 3.85 and Median: 3.00

# %% [markdown]
# ### 6E

# %%
print(f"""Considering that the white wine has higher quality, alcohol, and residual sugar than the red wine:
- Quality Mean Difference: {comparedq:.3f}
- Alcohol Mean Difference: {compareda:.4f}
- Residual Sugar Mean Difference: {compareds:.2f} and Median Difference: {comparedmedians:.2f}

We can safely say that alcohol and residual sugar levels have an influence on quality!""")
# Out:
# Considering that the white wine has higher quality, alcohol, and residual sugar than the red wine:
# - Quality Mean Difference: 0.242
# - Alcohol Mean Difference: 0.0913
# - Residual Sugar Mean Difference: 3.85 and Median Difference: 3.00
#
# We can safely say that alcohol and residual sugar levels have an influence on quality!

# %% [markdown]
# ### 7

# %% [markdown]
# #### Age, acidity and possible pH levels

# %% [markdown]
# ### 8

# %%
bins5 = [0,2,3,4,5]

# %%
pH5=datawine.groupby([(pd.cut(datawine.pH, bins5))]).count()
pH5
# Out:
# C:\Users\mikke\AppData\Local\Temp\ipykernel_32060\3891422029.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   pH=datawine.groupby([(pd.cut(datawine.pH, bins5))]).count()
#         fixed acidity  volatile acidity  citric acid  residual sugar  \
# pH
# (0, 2]              0                 0            0               0
# (2, 3]            546               546          546             546
# (3, 4]           5949              5949         5949            5949
# (4, 5]              2                 2            2               2
#
#         chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# pH
# (0, 2]          0                    0                     0        0     0
# (2, 3]        546                  546                   546      546   546
# ...

# %%
bins10 = [0,2.6,2.8,3,3.2,3.4,3.6,3.8,4,4.2,4.4]

# %%
pH10=datawine.groupby([(pd.cut(datawine.pH, bins10))]).count()
pH10
# Out:
# C:\Users\mikke\AppData\Local\Temp\ipykernel_32060\167956584.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   pH10=datawine.groupby([(pd.cut(datawine.pH, bins10))]).count()
#             fixed acidity  volatile acidity  citric acid  residual sugar  \
# pH
# (0.0, 2.6]              0                 0            0               0
# (2.6, 2.8]             10                10           10              10
# (2.8, 3.0]            536               536          536             536
# (3.0, 3.2]           2684              2684         2684            2684
# (3.2, 3.4]           2483              2483         2483            2483
# (3.4, 3.6]            693               693          693             693
# (3.6, 3.8]             84                84           84              84
# ...

# %% [markdown]
# #### The group between 3.0 and 3.2 pH are the densest/biggest

# %% [markdown]
# ### 9

# %%
datawine.select_dtypes(include=[np.number]).columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
ndf = datawine.select_dtypes(include=[np.number])

# %%
corrmat = ndf.corr()
corrmat
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000          0.219008     0.324436
# volatile acidity           0.219008          1.000000    -0.377981
# citric acid                0.324436         -0.377981     1.000000
# residual sugar            -0.111981         -0.196011     0.142451
# chlorides                  0.298195          0.377124     0.038998
# free sulfur dioxide       -0.282735         -0.352557     0.133126
# total sulfur dioxide      -0.329054         -0.414476     0.195242
# density                    0.458910          0.271296     0.096154
# pH                        -0.252700          0.261454    -0.329808
# sulphates                  0.299568          0.225984     0.056197
# alcohol                   -0.095452         -0.037640    -0.010493
# quality                   -0.076743         -0.265699     0.085532
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(corrmat, annot=True)
plt.show()

# %% [markdown]
# #### Alcohol have the most profane impact on quality

# %% [markdown]
# ### 10

# %%
dred.select_dtypes(include=[np.number]).columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
ndfred = dred.select_dtypes(include=[np.number])

# %%
corrmatred = ndfred.corr()
corrmatred
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
dwhite.select_dtypes(include=[np.number]).columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
ndfwhite = dwhite.select_dtypes(include=[np.number])

# %%
corrmatwhite = ndfwhite.corr()
corrmatwhite
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.022697     0.289181
# volatile acidity          -0.022697          1.000000    -0.149472
# citric acid                0.289181         -0.149472     1.000000
# residual sugar             0.089021          0.064286     0.094212
# chlorides                  0.023086          0.070512     0.114364
# free sulfur dioxide       -0.049396         -0.097012     0.094077
# total sulfur dioxide       0.091070          0.089261     0.121131
# density                    0.265331          0.027114     0.149503
# pH                        -0.425858         -0.031915    -0.163748
# sulphates                 -0.017143         -0.035728     0.062331
# alcohol                   -0.120881          0.067718    -0.075729
# quality                   -0.113663         -0.194723    -0.009209
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(corrmatred, annot=True)
plt.title('Red Wine', fontsize=16, pad=20)
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(corrmatwhite, annot=True)
plt.title('White Wine', fontsize=16, pad=20)
plt.show()

# %% [markdown]
# #### Alcohol har still the one that has the most profane impact on quality

# %% [markdown]
# ### 11

# %%
datawine['residual sugar'].hist(bins=10, figsize=(8, 6))
plt.suptitle('Histograms of Residual Sugar')
plt.show()

# %%
datawine['residual sugar'].quantile([0.05, 0.25, 0.50, 0.75, 0.95])
# Out:
# 0.05     1.2
# 0.25     1.8
# 0.50     3.0
# 0.75     8.1
# 0.95    15.0
# Name: residual sugar, dtype: float64

# %%
sns.boxplot(datawine['residual sugar'])
# Out:
# <Axes: ylabel='residual sugar'>

# %%
from scipy import stats
z = np.abs(stats.zscore(datawine['residual sugar']))
print(z)
# Out:
# 0       0.744778
# 1       0.597640
# 2       0.660699
# 3       0.744778
# 4       0.744778
#           ...
# 4893    0.807837
# 4894    0.537425
# 4895    0.891916
# 4896    0.912936
# 4897    0.975995
# Name: residual sugar, Length: 6497, dtype: float64

# %%
lower_threshold_z = -3
upper_threshold_z = 3

outlier_indices = np.where((z > upper_threshold_z) | (z < lower_threshold_z ))[0]
outlier_index_labels = datawine.iloc[outlier_indices].index
no_outliers = datawine.drop(outlier_index_labels)
print("Original DataFrame:", datawine.shape)
print("DataFrame after Removing Outliers:", no_outliers.shape)
# Out:
# Original DataFrame: (6497, 13)
# DataFrame after Removing Outliers: (6464, 13)

# %% [markdown]
# ### 12

# %%
datawinedrop = datawine.drop(['fixed acidity', 'citric acid', 'residual sugar', 'free sulfur dioxide', 'total sulfur dioxide', 'density', 'pH', 'sulphates'], axis=1)

# %%
datawinedrop
# Out:
#       volatile acidity  chlorides  alcohol  quality wine type
# 0                 0.70      0.076      9.4        5       red
# 1                 0.88      0.098      9.8        5       red
# 2                 0.76      0.092      9.8        5       red
# 3                 0.28      0.075      9.8        6       red
# 4                 0.70      0.076      9.4        5       red
# ...                ...        ...      ...      ...       ...
# 4893              0.21      0.039     11.2        6     white
# 4894              0.32      0.047      9.6        5     white
# 4895              0.24      0.041      9.4        6     white
# 4896              0.29      0.022     12.8        7     white
# 4897              0.21      0.020     11.8        6     white
#
# [6497 rows x 5 columns]

# %% [markdown]
# ### 13

# %%
pd.set_option('future.no_silent_downcasting', True)

# %%
datawinedrop['wine type'] = datawinedrop['wine type'].replace({"red": 0, "white": 1, '': 2})

# %% [markdown]
# ### 14

# %%
datawinedrop.sample(10)
# Out:
#       volatile acidity  chlorides  alcohol  quality  wine type
# 1199              0.58      0.076      9.5        6          0
# 1113              0.18      0.047     10.7        5          1
# 851               0.38      0.042      9.4        5          1
# 4213              0.38      0.142     10.1        4          1
# 4365              0.19      0.063      9.1        5          1
# 3244              0.21      0.020     13.4        7          1
# 1156              0.30      0.054      9.0        6          1
# 3703              0.24      0.050      9.1        6          1
# 3699              0.30      0.087      9.8        5          1
# 2348              0.26      0.029     12.2        6          1
